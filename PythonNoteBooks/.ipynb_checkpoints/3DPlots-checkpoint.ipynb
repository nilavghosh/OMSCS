# %%
# %matplotlib inline
from sympy.mpmath import *
f = lambda x, y: sin(x+y)*cos(y)
splot(f, [-pi,pi], [-pi,pi])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-af7a155bc8eb> in <module>()
#       2 from sympy.mpmath import *
#       3 f = lambda x, y: sin(x+y)*cos(y)
# ----> 4 splot(f, [-pi,pi], [-pi,pi])
#
# C:\Python27_x64\lib\site-packages\sympy\mpmath\visualization.pyc in splot(ctx, f, u, v, points, keep_aspect, wireframe, file, dpi, axes)
#     227         points = [points, points]
#     228     M, N = points
# --> 229     u = pylab.linspace(ua, ub, M)
#     230     v = pylab.linspace(va, vb, N)
#     231     x, y, z = [pylab.zeros((M, N)) for i in xrange(3)]
#
# C:\Python27_x64\lib\site-packages\numpy\core\function_base.pyc in linspace(start, stop, num, endpoint, retstep, dtype)
#      91     stop = stop * 1.
#      92
# ---> 93     dt = result_type(start, stop, float(num))
#      94     if dtype is None:
#      95         dtype = dt
#
# ...

# %%
r, R = 1, 2.5
f = lambda u, v: [r*cos(u), (R+r*sin(u))*cos(v), (R+r*sin(u))*sin(v)]
splot(f, [0, 2*pi], [0, 2*pi])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-65b12d2f0844> in <module>()
#       1 r, R = 1, 2.5
#       2 f = lambda u, v: [r*cos(u), (R+r*sin(u))*cos(v), (R+r*sin(u))*sin(v)]
# ----> 3 splot(f, [0, 2*pi], [0, 2*pi])
#
# C:\Python27_x64\lib\site-packages\sympy\mpmath\visualization.pyc in splot(ctx, f, u, v, points, keep_aspect, wireframe, file, dpi, axes)
#     227         points = [points, points]
#     228     M, N = points
# --> 229     u = pylab.linspace(ua, ub, M)
#     230     v = pylab.linspace(va, vb, N)
#     231     x, y, z = [pylab.zeros((M, N)) for i in xrange(3)]
#
# C:\Python27_x64\lib\site-packages\numpy\core\function_base.pyc in linspace(start, stop, num, endpoint, retstep, dtype)
#      91     stop = stop * 1.
#      92
# ---> 93     dt = result_type(start, stop, float(num))
#      94     if dtype is None:
#      95         dtype = dt
#
# ...

# %%
from sympy import symbols
from sympy.plotting import plot3d
from sympy import sin,cos
from sympy.utilities.lambdify import lambdify
x, y = symbols('x y')
f1 = lambdify((x,y),sin(x+y)*cos(y))
f = lambda x, y: sin(x+y)*cos(y)
plot3d(sin(x+y)*cos(y), (x, -pi, pi), (y, -pi, pi))

# %%
from sympy.abc import x
from sympy import sin, series
from sympy.utilities.lambdify import lambdify

import numpy as np
import matplotlib.pyplot as plt


func = sin(x)/x
taylor = series(func, n=6).removeO()

evalfunc = lambdify(x, func, modules=['numpy'])
evaltaylor = lambdify(x, taylor, modules=['numpy'])

t = np.linspace(-5.5, 5.5, 100)
plt.plot(t, evalfunc(t), 'b', label='sin(x)/x')
plt.plot(t, evaltaylor(t), 'r', label='Taylor')
plt.legend(loc='best')
plt.show()

# %%
from sympy import sin,cos
r, R = 1, 2.5
f = lambda u, v: [r*cos(u), (R+r*sin(u))*cos(v), (R+r*sin(u))*sin(v)]
splot(f, [0, 2*pi], [0, 2*pi])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-219078ae4a14> in <module>()
#       2 r, R = 1, 2.5
#       3 f = lambda u, v: [r*cos(u), (R+r*sin(u))*cos(v), (R+r*sin(u))*sin(v)]
# ----> 4 splot(f, [0, 2*pi], [0, 2*pi])
#
# C:\Python27_x64\lib\site-packages\sympy\mpmath\visualization.pyc in splot(ctx, f, u, v, points, keep_aspect, wireframe, file, dpi, axes)
#     227         points = [points, points]
#     228     M, N = points
# --> 229     u = pylab.linspace(ua, ub, M)
#     230     v = pylab.linspace(va, vb, N)
#     231     x, y, z = [pylab.zeros((M, N)) for i in xrange(3)]
#
# C:\Python27_x64\lib\site-packages\numpy\core\function_base.pyc in linspace(start, stop, num, endpoint, retstep, dtype)
#      91     stop = stop * 1.
#      92
# ---> 93     dt = result_type(start, stop, float(num))
#      94     if dtype is None:
#      95         dtype = dt
#
# ...

# %%
from sympy import symbols
from sympy.plotting import plot3d
from sympy import sin,cos
from sympy.utilities.lambdify import lambdify
x, y = symbols('x y')
u, v = symbols('u v')
f1 = lambdify((x,y),sin(x+y)*cos(y))
f = lambda x, y: sin(x+y)*cos(y)
r, R = 1, 2.5
plot3d([r*cos(u), (R+r*sin(u))*cos(v), (R+r*sin(u))*sin(v)], (u, 0, 2*pi), (v, 0, 2*pi))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-3d49f39d66b7> in <module>()
#       8 f = lambda x, y: sin(x+y)*cos(y)
#       9 r, R = 1, 2.5
# ---> 10 plot3d([r*cos(u), (R+r*sin(u))*cos(v), (R+r*sin(u))*sin(v)], (u, 0, 2*pi), (v, 0, 2*pi))
#
# C:\Python27_x64\lib\site-packages\sympy\plotting\plot.pyc in plot3d(*args, **kwargs)
#    1614     series = []
#    1615     plot_expr = check_arguments(args, 1, 2)
# -> 1616     series = [SurfaceOver2DRangeSeries(*arg, **kwargs) for arg in plot_expr]
#    1617     plots = Plot(*series, **kwargs)
#    1618     if show:
#
# TypeError: 'NoneType' object is not iterable

# %%
from sympy.mpmath import *
f = lambda x, y: sin(x+y)*cos(y)
splot(f, [-pi,pi], [-pi,pi])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-3c8c4adad1d6> in <module>()
#       1 from sympy.mpmath import *
#       2 f = lambda x, y: sin(x+y)*cos(y)
# ----> 3 splot(f, [-pi,pi], [-pi,pi])
#
# C:\Python27_x64\lib\site-packages\sympy\mpmath\visualization.pyc in splot(ctx, f, u, v, points, keep_aspect, wireframe, file, dpi, axes)
#     227         points = [points, points]
#     228     M, N = points
# --> 229     u = pylab.linspace(ua, ub, M)
#     230     v = pylab.linspace(va, vb, N)
#     231     x, y, z = [pylab.zeros((M, N)) for i in xrange(3)]
#
# C:\Python27_x64\lib\site-packages\numpy\core\function_base.pyc in linspace(start, stop, num, endpoint, retstep, dtype)
#      91     stop = stop * 1.
#      92
# ---> 93     dt = result_type(start, stop, float(num))
#      94     if dtype is None:
#      95         dtype = dt
#
# ...

# %%
from sympy import symbols
from sympy.plotting import plot3d
from sympy import sin,cos
from sympy.utilities.lambdify import lambdify
x, y = symbols('x y')
f1 = lambdify((x,y),sin(x+y)*cos(y))
f = lambda x, y: sin(x+y)*cos(y)
plot3d((x+2*y), (x, -pi, pi), (y, -pi, pi))
